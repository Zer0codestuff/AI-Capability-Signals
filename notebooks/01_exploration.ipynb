# %% [markdown]
# # AI Capability Signals Exploration\n\nRun the pipeline first, then use this notebook to inspect processed tables and reproduce key slices.\n

# %%
from pathlib import Path\nimport pandas as pd\nROOT = Path('..').resolve()\nmodels = pd.read_csv(ROOT / 'data/processed/models_master.csv')\npricing = pd.read_csv(ROOT / 'data/processed/pricing_openrouter.csv')\nmodels.head(), pricing.head()\n

# %%
pricing.sort_values('context_window', ascending=False).head(20)[['canonical_model','context_window','input_usd_per_1m','output_usd_per_1m']]\n
